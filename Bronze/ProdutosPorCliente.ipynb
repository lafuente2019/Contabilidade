# %%
# %run /Workspace/Users/valterlafuentejunior@gmail.com/Contabilidade/Config/config

# %%
# %run /Workspace/Users/valterlafuentejunior@gmail.com/Contabilidade/Utils/utils

# %%
import pandas as pd
from pyspark.sql import functions as F
from delta.tables import DeltaTable
from pyspark.sql.window import Window

# %%
tabela_destino_config = "workspace.bronze_contabilidade.config_clientes"
tabela_destino_produto = "workspace.bronze_contabilidade.produto_clientes"

# %%
# Caminhos dos arquivos no workspace Databricks
path_config_bronze    = "/Volumes/workspace/bronze_contabilidade/dadosclientes/config_contabilidade (1).xlsx"
path_produtos_bronze  = "/Volumes/workspace/bronze_contabilidade/dadosclientes/produtos_contabilidade (1).xlsx"

# %%
df_config_bronze = pd.read_excel(path_config_bronze)
df_produto_bronze = pd.read_excel(path_produtos_bronze)

# %%
df_config = spark.createDataFrame(df_config_bronze)
df_produto = spark.createDataFrame(df_produto_bronze)

# %%
df_config = df_config.withColumn('data_execucao', F.current_timestamp())

df_produto = df_produto.withColumn('data_execucao', F.current_timestamp())

# %%
merge_config(df_config, tabela_destino_config)
merge_delta_produto(df_produto, tabela_destino_produto)
