# %%
# %run /Workspace/Users/valterlafuentejunior@gmail.com/Contabilidade/Utils/utils

# %%
from pyspark.sql import functions as F, Window

# %%
# Tabelas de origem (Bronze)
tabela_bronze_config   = "workspace.bronze_contabilidade.config_clientes"
tabela_bronze_produtos = "workspace.bronze_contabilidade.produto_clientes" 
tabela_destino_silver = "workspace.silver_contabilidade.calculos_custo_margem"

# %%
df_config_bronze   = spark.table(tabela_bronze_config)
df_produtos_bronze = spark.table(tabela_bronze_produtos)

# %%
df_config_bronze = df_config_bronze.withColumn(
    "mes_referencia",
    F.to_date("mes_referencia", "yyyy-MM-dd")
)

# %%
df_produtos_bronze = df_produtos_bronze.withColumn(
    "mes_referencia",
    F.to_date("mes_referencia", "yyyy-MM-dd")
)

# %%
df = calcular_custos_e_margens_silver(df_produtos_bronze, df_config_bronze)

# %%
merge_silver(df, tabela_destino_silver)
