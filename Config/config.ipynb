# %%
# %pip install openpyxl

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.bronze_contabilidade
COMMENT 'Camada Bronze para armazenamento de dados brutos';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.silver_contabilidade
COMMENT 'Camada Silver para armazenamento de dados tratados';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.gold_contabilidade
COMMENT 'Camada Golf para armazenamento de dados prontos para uso';
