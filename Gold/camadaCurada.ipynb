# %%
from delta.tables import DeltaTable
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from pyspark.sql import DataFrame

# %%
# %run /Workspace/Users/valterlafuentejunior@gmail.com/Contabilidade/Utils/utils

# %%
tabela_silver = "workspace.silver_contabilidade.calculos_custo_margem"
tabela_gold_cliente = "workspace.gold_contabilidade.cliente_gold"
tabela_gold_produto = "workspace.gold_contabilidade.produto_gold"
tabela_gold_prejuizo = "workspace.gold_contabilidade.prejuizo_gold"

# %%
df_silver = spark.table(tabela_silver)

# %%
gold_produto, gold_cliente = gerar_gold_contabilidade(df_silver)
gold_prejuizo = gold_produtos_maior_prejuizo(df_silver)

# %%
merge_delta_gold(gold_produto, tabela_gold_produto)
merge_delta_gold(gold_prejuizo, tabela_gold_prejuizo)
